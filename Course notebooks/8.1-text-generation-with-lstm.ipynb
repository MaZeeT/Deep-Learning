# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 2s 3us/step
# Corpus length: 600901

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200281/200281 [==============================] - 197s 983us/step - loss: 1.9735
# --- Generating with seed: "! we are
# woven into a strong net and garment of duties, and "
# ------ temperature: 0.2
# ! we are
# woven into a strong net and garment of duties, and dispority and and the distincts, and the still the something the strenting the sense in the sense in the sense it is the strength of the still and the sense the sentations and sense in the sense and the degener to the sense and in the sense from the perhaps and the sense and the sense and in the strange to the presented the sense in the sense the still the man to the sense in the sense and the sti
# ------ temperature: 0.5
# ense the still the man to the sense in the sense and the stiplisting in the prosent and perhaps the even the cristion to the sense in love the end and contacuines of the develous so the stire who have a constion to the tevered in it which he astance, and and himself in the seading the sense the saced that is the strange. the end in the stranges the frexting and power sense which the parting in the world and the belises the interpectially and lather all the
# ------ temperature: 1.0
#  world and the belises the interpectially and lather all the
# in its to which ablus a we. man-and to siing but the hother will. hopeinare our, "fen sepir the are it disinfrerdmet, enpressstsusted, degense and low? a seinces.=--what is pottes of mand ldemorj=-and base it: to inselves they self-curilitthided that "by stonory, spirity hithertories of namuely the
# deal eac end
# sermable pogriake and inol. ,nese
# mirstore the to maverx.
#
# 2x5. in the latous the cont
# ------ temperature: 1.2
# . ,nese
# mirstore the to maverx.
#
# 2x5. in the latous the conteculip and rais. "fle_ ware vileents, every man rearvated-wivener pusal sp menot niftingunt, laygeck, and actnaryided the degreanars
# inerequiturik of which, and beinkin,, se pates, thirms--thnerd"ly condicicloo.  dus to a self-couth"urs, dis,statefulal, contirence digweces--ya the noquely the clasmaus of
# consrome vatw,
# for the whito uan no, desin spreces
# to be wesse of ngcially ismora
# ivinkune
# mor
# epoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 176s 880us/step - loss: 1.6165
# --- Generating with seed: " "naive" on that account give them commendation for a defect"
# ------ temperature: 0.2
#  "naive" on that account give them commendation for a defect and the man and the spirit and every and the fact and the sense of the man and the self--a man and the man and all the surption of the man and the self--and the self-same to the self--and the man and the self--and to the promance and the straise of the something to the man and the spirit and the self--and and the self-supenity and that the provise of the surpless and the persons of the last himse
# ------ temperature: 0.5
# he provise of the surpless and the persons of the last himself as means and the man and the reasons of a some and the spirit and tratams to the prohoss and possible and only--who has insignt and every prohaps be the spirit and the man of their world
# be a good discirety by the individual tood too thrist the parce of the man has believe that a historical taste mankind of the world in the problem to was desires of the also any intertituals too intercesscial r
# ------ temperature: 1.0
# was desires of the also any intertituals too intercesscial rather will, i  evil made. to suppeciament (all withous they brorech usistration is menser,
# as tome
# hay distrusti.
# to equally.--no that is  endable only interdiviam who gencemoumantal good may tal germat faturely, or it is still, and but then sense as a sledisaling of the
# aistul fortive surm--pristrord worrn any guiled to tram. been puttist andisuntious that ceried from effer metlerming esting impo
# ------ temperature: 1.2
# t andisuntious that ceried from effer metlerming esting impose
# will
# olself", to all  as rands than calles.
#
# 1h0. br. is impruseives apphialing went to "imongy of timate, altwons duep of couse,ness people, or to wanco weally. means--toroquity in
# which perber is ?us work, !und
# merloragious immain become met obverowtit by stramar. =n'ys., and carave, are to evolway togal stipely
# to daid ter-embomenties, in fairh.
#
# , .
#
# knorlity only ele? thorome: yeaus and a
# epoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 187s 934us/step - loss: 1.5280
# --- Generating with seed: "rding to the best logicians, is belief. at the
# foundation of"
# ------ temperature: 0.2
# rding to the best logicians, is belief. at the
# foundation of the sure of the most sure of the sure and subtle as the sure and sure and sure and mankind and spirit of the principle and superficially in the same to self-comes the conscience of the senses and sure of the short, and stand something and sure and spirit of the sure and soul as the conscience of the same time the sure of the same to the sure is the same to the sense of the same to be not the frea
# ------ temperature: 0.5
# sure is the same to the sense of the same to be not the freadows has a dangerous good as one and almost of conscience of the self-complanting the art to the great spirit or germinity is the cases he does little that he spirit, and the master of the light. the pares and same, the love the transfersatical and misdure has a problem of conscience to the spirit and stand of the sure was problems of the most more of there is once think as it is always really as
# ------ temperature: 1.0
#  most more of there is once think as it is always really as this bews what censewar, a religious they expossioning
# vitu of, boubagationb"zing too the repoment fron
# rarely powan sived be enducative
# expation foolus of distinguisgness," in recessially geal,
# force, no longere, and
# necessariy than a trud effecist europet by the mortwerhopless of satication. no "one rainnance whyther apparancestorate,
# heregands certain a dame; as just "command of , he dund a caw
# ------ temperature: 1.2
# eregands certain a dame; as just "command of , he dund a cawarly
# necipage, or atteric, and strecaing, of
# traudugaripr fure accoid relaring woman with hat no
# low alpregance he art hbus science of fore, and specially tooc"sty lofishy. no look tele--eur, cause, on cave; in "screptims, as padeirests, morabs orfnody our ranted only als a alblered a thina impul of modni-that,-izadical,
# het aphed and tradilusion. the world of kismes of the runed it they worrs tha
# epoch 4
# Epoch 1/1
# 200281/200281 [==============================] - 174s 868us/step - loss: 1.4833
# --- Generating with seed: "y discredited. there always remains, however, the
# possibilit"
# ------ temperature: 0.2
# y discredited. there always remains, however, the
# possibility and the surernally in the same believed the subjection of the presention of the sureful and the world of the subjective and such a man of the part of the believed and the demonsticists of the subjection of the philosopher and the endured the experience and the subjection of the presention of the surprised and the presention of the action of the surerntial of the part of the problem of the surern
# ------ temperature: 0.5
# n of the surerntial of the part of the problem of the surernarp of his own its dare and sulfer of his such a simslang, the moral more as a sacrifice the contained and their spirits and the consciousness of the weacter and a assure and effects for even after the "good is partiately, of ever as the more as the world of philosopher and surder that whilling who is a sense to the as
# and expression of justic of the longer such a should world of perhaps reful the
# ------ temperature: 1.0
# ustic of the longer such a should world of perhaps reful the means intellection, the other
# arthunism to the very depreised duing of the lomes
# just? it is been rongloogm1. i "pribotious interrecomarner in his weast deisnopnics which is the inferinke falm, for a sprear experience, does he sailf-gexpomestans the comment and that objess and
# suyes, whose
# conceived and the
# willler of higher
# knowld adrughtun to hence protalism of even to  'the "mortally and dirc
# ------ temperature: 1.2
# ghtun to hence protalism of even to  'the "mortally and dirccirity,
# wors of respolitics mornary palism, perhapvionition. the free surpranition. that it. my ows it. asmo,s an act i alt one though unintication. old, erron
# in the learn order that
# orksocedct "very
# hyurgness
# illiminer too
# yet toteng(0' is knows
# possibilinariesio
# ly of hound: and
# conduct.--than sighed whole gerselvisism (and germans wowch is justic clanter even there. the high hnm issquence." co
# epoch 5
# Epoch 1/1
# 200281/200281 [==============================] - 177s 882us/step - loss: 1.4511
# --- Generating with seed: "sible. this constitutes the antagonism between the
# specialti"
# ------ temperature: 0.2
# sible. this constitutes the antagonism between the
# specialting the present been in the person the same to the great stronger and man and something the still the same of the superficially and man is the reason of the person of the soul and the soul and the sense of the person to the same to the life of the present his his with the sense of the person of the sense of the soul and the sense of the present with the reason of the person the present his his his
# ------ temperature: 0.5
# esent with the reason of the person the present his his his history, which an one's object and also be the every be for the earth to the will of supersion, as his hous destrays of assimans and the same time to this way the natural of the herd so conscience in the person for a still being who are only a his been some present in the perhaps reason of the time all the increased to the truth of the point of a something in the last also and believe the last all
# ------ temperature: 1.0
# int of a something in the last also and believe the last all other adlaining. a repth as been adblience of lumbed and alls society a ficed and
# other" of the cerre-pautic disity and human othing the infermardd and a so eure and
# scection of the pureiariby man
# anything the "dispress of the has not eaches a certains, which now exception of fatired of destrays
# and better, of presence whose ahvtes: and
# have trieity of
# in indevedated to doubt in orders the
# reason
# ------ temperature: 1.2
# have trieity of
# in indevedated to doubt in orders the
# reasondon of the award, and
# assipontence, but fal oppose =quibe enjoys in the roodly nemburi andary matters accordenve, the ""backgance, if us as
# estbold atome and has assest of gratines-side. be venery.
#
# 220
#
# assess--is been, with."
# a sexires magned again, who t in-ar by every hen popbisilicism under
# the come
# as which the remained,e, on uefowical
# lifesogert ti edediality me.
# honondeld. the otwame. no (
# epoch 6
# Epoch 1/1
# 200281/200281 [==============================] - 188s 938us/step - loss: 1.4295
# --- Generating with seed: "r effects its ultimate consequences
# every moment. granted th"
# ------ temperature: 0.2
# r effects its ultimate consequences
# every moment. granted the self such a self self and words of the sense of the sense of the sense of the sense of the sense of the same to the self are false of the sense of the surress of the saint of the same to the sense of the same to the salvation of the sense of the same to state of the same to the sense of the same to the sense of the strength of the sense of the self such a self self and states of the sense of the
# ------ temperature: 0.5
#  of the self such a self self and states of the sense of the spirit of a men must be prince we cause of man is to the entir pleasure in the still one is necessary in the sense for present with the same soul: the most stortander, and the some
# the same a delive to be to the deal to the sight that the sense of lives and the sense and the state of the very will of a distinctively of the same
# forming as a man ends from a say to himself the false and princing th
# ------ temperature: 1.0
# s a man ends from a say to himself the false and princing them was way philosophy
# as the food or puting that hith which a utility a soul, that of love presarfation of the long--norut criticistsiqure, may sure--the an foreignable
# end,
# such higher a
# prinking
# higher happen, to graet or, the backmer--win no
# quest for
# tragdated in regreslly find drongminatoly the prover and consequences"--vird feernce, that i have again--cality,
# for one world, a caysent woman
# w
# ------ temperature: 1.2
#  that i have again--cality,
# for one world, a caysent woman
# who is :ow
# that atrtaking, who dever man very braised ofpariand to empreorovis to higherifret bain bruttenam and predisent
# belief sham
# suspead to be footnoms in util.--the psjchously, the
# rolow,--with, master: the fakey, ri? so own life from ears us
# more, obligibumstole other, fry who are no
# =ivise or deepo--delieful, synthered and rath know cable rele-ejeding yduce recoti. have
# labon.
# sulfor etsif
# epoch 7
# Epoch 1/1
# 200281/200281 [==============================] - 228s 1ms/step - loss: 1.4131
# --- Generating with seed: "sense of ding. sache is of very
# indefinite application (res)"
# ------ temperature: 0.2
# sense of ding. sache is of very
# indefinite application (res) be the moral strength of the comparative and has a more into the compares of the same the same of the condernal and stronged the soul is always and spiritual secrething to the same the moral and self-men, the superion of the stronged the really and the comparative conscience to the proved and the world is a soul is the stronges and consciety and strength of the compares, and the moral and the str
# ------ temperature: 0.5
# iety and strength of the compares, and the moral and the strange and severe of men, and state be dealing as the personal as a complete and probable to be above all the transe--the really the thing and hard in the love of the free good of an its the the mask of the fact of the most superduling of the moral estimate and sentence and believe the more inconceds to the valuation.=--it is at all hows the destruct a man of the fact of the way the possesses has be
# ------ temperature: 1.0
# e destruct a man of the fact of the way the possesses has been are preced are
# seous, or belief flove of princious later the compouts with, in it
# is doubt intitude; as
# che
# betick in
# order for kinly happiness as in the soul of time hard one--is and men, to feel trageling: that
# sensual contideic of the trughality man soech, and traut infromin tention sympathy abives, in the philosopher is, histories exaccicienative.--all norgenest codeases of the eeas in the
# ------ temperature: 1.2
# exaccicienative.--all norgenest codeases of the eeas in the ewas world, force out of hiscewisrs frovely, by almost rehardens, =defects.--promptled lether pitive as
# a preor, ranks. one beent. it. this extrujathbdencab; itself mobe tyls but he had
# hied no slasely ye works and
# striffled, ore wall the sad" but had disofong; for spirit off
# egois from
# when is u not itudied, for knowledg, thereby to
# suith in eye that it hungerdent huntevous, frantic mainfuct of t
# epoch 8
# Epoch 1/1
# 200281/200281 [==============================] - 254s 1ms/step - loss: 1.3979
# --- Generating with seed: " is the body in which the spirit works. does a huge boulder "
# ------ temperature: 0.2
#  is the body in which the spirit works. does a huge boulder and such and the an and soul and the present to the sense of the saint and distrust and man and that the fact the an instance of the strength of the such an account to the sacrifice and seek and an endogmest the conditions to the present and an expression to the same and the senses to the deceive and soul the sacrifice the such a strength and also a matter and man is the sense the such a desires a
# ------ temperature: 0.5
#  and also a matter and man is the sense the such a desires and the one may feel as to distinction is also to the same over made a state of which is the saint the particlous, is a man implicially still that the desires the antiture of the reasely and spirit and and the contradicted all the bad. a person this an and concerned and all the
# any or also and also begen the strength and desprence to the
# distinction of according to the fact to the "conditions harms
# ------ temperature: 1.0
# istinction of according to the fact to the "conditions harms. he wilhn parttinghisies, had a states:--there are, to such many him no resids cawable firstty bark and this completed affords or in the premises sympathy also en
# anwicaryes--and not from a contradicts of the fact our beyongoot, and backpoled! noly cleates and worlls elected and man briefle engrarn and pogtised artistic estimated social corres call. the absolutely and
# cumen
# pleasure,
# harder, "eve
# ------ temperature: 1.2
# corres call. the absolutely and
# cumen
# pleasure,
# harder, "ever "puning
# that by sprefack as the connection.=--abuely
# question to loy the dank
# we have a quagles. it had acfulish wold
# take exception founder," is naturamikeary
# he xedness upon refements" thus it: every ferous proved out of insuspite. that formed of law short, a sensiven fortholder may there one'-creation of peryletraweris mons time: thus he hust hardly: one' mitthing myecoint itself.
# beworv,,
# on
# epoch 9
# Epoch 1/1
# 200281/200281 [==============================] - 285s 1ms/step - loss: 1.3861
# --- Generating with seed: "nto the higher, finer, and rarer), or
# deteriorations and mon"
# ------ temperature: 0.2
# nto the higher, finer, and rarer), or
# deteriorations and monstrects of the standard of the same of the standard of the strength of the states to the spirit of the conscience of the present as the conscience of the conscience of the soul of the constitute of the present and more moral strength of the saints of the soul of the soul of the same to which the same to the standards of the present the same of the deceived and the same to the standarn and somethin
# ------ temperature: 0.5
# me of the deceived and the same to the standarn and something enough to his taste of present to favour and something and standarn to power of superstitions and reading and conceptions of the greater of the present at listing upon superstition of the life of an end in the world, the stand reading the soul is the distrust and for the truth and more sufficiently, to the more silence and had to strength, the soul, and the still must be daring the distingual so
# ------ temperature: 1.0
# th, the soul, and the still must be daring the distingual soul, and casting with these good twose of our different
# more
# collicateur, lived ingood, with power should liver of gimates to a "dungton when
# the moral
# athers disoptherle,
# onm sanda
# more arouse enespal, acts of victoricatire is by the exceptions in such a more order of europe sun-gratifle, pray his
# semble paring if i modest. to oeening laqual that of revolves flamal of
# instined with its
# decisedude
# ------ temperature: 1.2
# ual that of revolves flamal of
# instined with its
# decisedude is !vound elective toked englisht with i fliis anmseow will findgems to cmatiene," , hand
# nis repulenc; when once has," srepticial comethy wh)-quectes of sensated as divegtion is i me, at hics
# and
# superately.
#
# 1no, sochears. yet stean? even ytembervan forment also obakion to inactause
# tody everything themly barfratments of loveh good over and
# corition stifmhed from ights laws they did it as it in
# epoch 10
# Epoch 1/1
#  87424/200281 [============>.................] - ETA: 2:42 - loss: 1.3557

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
