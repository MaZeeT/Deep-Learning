# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.4'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 583s 3ms/step - loss: 2.0011
# --- Generating with seed: "t is the burning alive of one
# individual compared with etern"
# ------ temperature: 0.2
# t is the burning alive of one
# individual compared with etern and strenction the conception the strengted the can of the self-conself that the the strenger and the self the contringless of the concepted the still to the farthere the conception of the conself that the stand of the the strengness of the strengen the problence of the fancer the self-the strenger and the strenger of the conception of the self-to the strenger the strenger the progess of the cons
# ------ temperature: 0.5
# he self-to the strenger the strenger the progess of the consequently which a more the progess of the order be the
# casted the self as self-to the conservent more the believes that the ragee of like the goder the age, the still supherence, that the enementence, as realsous propession to what deeter problence the demist have the true clain a slame proce, readonly, the strecter to its general case the propesse of the stringles and some the from the grome the e
# ------ temperature: 1.0
#  propesse of the stringles and some the from the grome the elizall-as their have pittain the hands troty anre alw menebe. there for has proftingly
# by the nems "avatuwed. is sters from bus before3edienenencos frostundering: it perhaps will ppire believe.
# "value thar men seele time the
# live on to the tane, has into be inscardster the priveried. ih
# sto be, reasont. but omparity of "
#
# jom
#
# "venences that the progod as very been as thrife impenbeis
# :oppendnted
# ------ temperature: 1.2
# hat the progod as very been as thrife impenbeis
# :oppendnted than e-wcangard. by
# c nodminc arsthend;--i attresedose
# dadgent ged are doectnce
# tanden--as"
# incivilence,, adserithing
# "a plalingrangaably,--prodoned symparsttharing bofigals, in
# gren iostlypaur lice society worted the, more develw a
# to just piloned (nnd acts. a deer pract onts-rimer does all themhevured a revening, chonge, which welictent toel. nobte feirouble, e:s-contases rany bad"nsif tlee way
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 615s 3ms/step - loss: 1.6401
# --- Generating with seed: " on a sudden, the entire movement of the world
# stopped short"
# ------ temperature: 0.2
#  on a sudden, the entire movement of the world
# stopped short the the sense of the more the fact of the sense of the secience and and and the sense of the same the sense of the same the sense of the such the supporing the will and the seem the believe of the extrance and the secience and the great the same and the seem the sangling the sense of the the such as the secience and the sense of the secience and the supporing the same the sense of the say and the
# ------ temperature: 0.5
# ence and the supporing the same the sense of the say and the
# best and putter and the sense of the wending to the love of the exceptions of the most this victoring to the save it is in the seeming in the sering good and a something this good
# the things and has sore the
# will the exerting past the ideal and nother in the self-continity of the same of the what in any result of the powerful one cunserve in the age and man consiter-inture
# suppirions of gratificu
# ------ temperature: 1.0
# e in the age and man consiter-inture
# suppirions of gratificuries of such the may if worany yet fot anuike reall transhing the great meence on itnes whle we fearing how
# soye from
# dan
# caulacidned they wortera, in the beden too sairstand of "naturice strange and elss" and poins--if this same unevery neurder, the bediept of hen in the
# hunt in and a masture hi, truth in any
# modern, it is by pargores of "hrather at
# inseption, must day
# and the more
# as to sumprees
# ------ temperature: 1.2
#  "hrather at
# inseption, must day
# and the more
# as to sumpreess but in
# prejuvious, efcewn fromd-laitic longers the evinestiloint of lequirely, the-eeffect be here, smullfloriest and persual makes. from of mane from "sary for huppeome,
# will he souls of aonhing
# what the
# more nothcisbsomes jorized
# be "an camgine with refance this,-"'theredize and "will nee and
# these the this oppain, thise as ale al
# that
# and shined hat. "the
# hero? h1ed pryhundent of the enre, ob
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 588s 3ms/step - loss: 1.5479
# --- Generating with seed: "as this is
# growing wearisome, i would now recommend for a ch"
# ------ temperature: 0.2
# as this is
# growing wearisome, i would now recommend for a child and self in the same of the compliss of the soul the sees the sees the honest the sense of the present to a state of the saint the sense of the state the sees the sentiment of the great the says the sense of the state of the compare of the strength the sense of the sentiment of the sense of the saint the explanation of the same the sense of the same and self and schould in the compare of the h
# ------ temperature: 0.5
# nse of the same and self and schould in the compare of the how to have into the virtuce that extent the refine and aristing to any most lingually the our moters of the effect in the compare, as as a self and seaser of the present the precisely in which do in the soul important to another man in into the profound the spirit to which the sense of the namely of russion the who and extent of the understand religious a far that things see the scientific what a
# ------ temperature: 1.0
# stand religious a far that things see the scientific what a regard of the motovours buch character the is, conspiriation
# capacity of
# the should from muchss in all entarm with which the seear we most commlaniginates these stind, these so happenuless, who howing incrumandsabme; sheirse and
# upon
# a advance of scernenoper, and ebole suffers to all incusser in fir these pirciy
# its viss it is "on
# the
# to knowlves out aftersained bethelical parks even the
# suchiter.
# ------ temperature: 1.2
# knowlves out aftersained bethelical parks even the
# suchiter. is has repress and selfsiby impressurs prepon in disguise"--that a virccic
# now furnotes of their is. in
# mulients of the sumentiglighess of the spiint of is 1creeny homangerourd in
# ignisism so who wack, delies
# incomposticence in this man
# schousn it, thet: is a men of
# dear a claistt,
# wreng to, any power.
#
#      that be idbecrafines. once
# feel regreed is vetary, amongraningenase of last ruckentilical
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 581s 3ms/step - loss: 1.5008
# --- Generating with seed: "the italian, the frenchman, and the englishman
# have done by "
# ------ temperature: 0.2
# the italian, the frenchman, and the englishman
# have done by the self-condition of the sense and the self-condition of the moral the secority for the stronger and the profound the secious the german seriends of the series and the german and the the self-circumstance of the sense of the german the states of the self-contemption of the self-conscience of the self-conduct the soul--and the self-conduction of the self-condition of the learned the self-conscious
# ------ temperature: 0.5
# tion of the self-condition of the learned the self-conscious philosophers and weak and for existenting, to be a nivelon with which a mast the proves the false. the fact and should not the sentiment of souls that the method minal intercolined man, the strengther, in the former may be self-cannord the ethical of the called and not be any divined the can be something responsible the earsow--and the temptation of the carrial in the nature is the world as in th
# ------ temperature: 1.0
# emptation of the carrial in the nature is the world as in the
# insike,
# they wane
# romanticleriy canculiable about exseciatism,"--whether which
# a distingle men. the naingener, whether goost oindret has cloines of
# symble divanity of their acts and general orgy to would arts in this have
# the be it is the good
# existence it will ouicl.
#
#
# is
#
# ard it well
# a teriest..
#
# 1der" the selet
# cly seffem of spiects"--but that
# every cordes, that the
# unfargility up one or is o
# ------ temperature: 1.2
# --but that
# every cordes, that the
# unfargility up one or is out. - hid still. not also takesom agaits and
# now" berlis oldic wear, of some proldtain tooustiloywealies'; best,uftell once" plouraned
# praceged in othe themoncingvororden healthine medend? to men-roman tran, but enpeks onager. where; in very eventas he whe which that
# is we have more has own from cheirsor brave, corour beforetovoures the traiety
# of the is child-iness", we in no longed to galle no g
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 599s 3ms/step - loss: 1.4712
# --- Generating with seed: "with their profound mediocrity,
# brought about once before a "
# ------ temperature: 0.2
# with their profound mediocrity,
# brought about once before a so the strengther and some conduct to the same such the strengther of the same existence of the soul is the strengther and the strength to the probable that it is a compare of the course of the some course of the strengther of the so the things and the states of the strong the soul of the same and the man is all the same and the transfort of the same the states and the existence of the sense of th
# ------ temperature: 0.5
#  of the same the states and the existence of the sense of the as a more the amoticged and that is the soul, it will to be all spirit of a same with his implant and even in the still
# in the powerful man so commour for powerful age to be the things and the course the the
# indial" and
# the for the man as some invention of a partice and to the do the to det the free that the sucher also the essentially self-same as a power than to german far as a soul of the pro
# ------ temperature: 1.0
# self-same as a power than to german far as a soul of the promesse of "okener
# of a pretouse bord
# a must: accordings to do will"
# spiish.--an even actions it
# simpleess of the hated musty ye-threath of free such as it. it is the warted to such when
# all a destrect of the really witning
# subcern praise fairly
# border, little yes nature, even this noble, so be
# insists
# as indacivestedners for all medencys in a man was
# cruelty, hunder for stames, on which an advance
# ------ temperature: 1.2
# n a man was
# cruelty, hunder for stames, on which an advance with succeg to see cause
# of unfeelly oppoded as the same dittually -imbelates.s
# sriens and who is haslout" oven, the wlike himself that
# extincy it good expense the ancomean yill human countimate too vatue with opposed stantly exists at rome  ? he essficaind ;every preamery
# clearly.--"for a
# lessly, i devilws, an occumsness, cruege for this compare of
# virius, by s botoph. perhaps
# to knowledge of
# cla
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 678s 3ms/step - loss: 1.4500
# --- Generating with seed: "tellectual haughtiness of the sufferer, this
# pride of the el"
# ------ temperature: 0.2
# tellectual haughtiness of the sufferer, this
# pride of the elevated the sense of the conscience and sense of the conscience of the sense of a manking the serient the sense of the sense of the conscience of the same the sense of the cannotoric of the conscience of the same all the same the sense of the strifest the sense of the sense of the fact the experience of the sense and the assumed the man with the conscience of the same one the fact and conscience of
# ------ temperature: 0.5
# th the conscience of the same one the fact and conscience of the same essentially the
# human in man as the precisely the constrance. the falsements, and belief the sense it is conscience of conscience of the strulgly precisely the morality of any man to disciplisies the the steps the conscience and with the secreted to the charactions of which man the
# discovered and accurtositive of the will to the certain and interperable with experience of the sense it is
# ------ temperature: 1.0
#  certain and interperable with experience of the sense it is their fundaung to their objege in the felse, make
# being poaral pluening, those good, whetheritomation that theorong.
#
# are, everyking which a
# ceases in immed ackness of belief their discoverong conscience through the personsly decepsing class all the pain, it origin respisest. it were everyme. it
# all to the solitis and troild strongly.
#
#
# 11
#
# =which selfoinse of soul and friently, the wants!--it is
# ------ temperature: 1.2
# 11
#
# =which selfoinse of soul and friently, the wants!--it is grouble, averenius, which is acts and peace of one bitlineiffonation is fact hoh deoped
# the whollers also, as it, late is
# a messon, or belief "the clessful ra me as to its for becomes, father lasss seldoman thy
# utly
# pertend (posse aices--and orlies." the influenes, and
# engloses will
# that uffed tixist--catos, of mark it windicllesss sufferigiet, has
# ypthlomshin reve", it hears religionss) rekinds
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 624s 3ms/step - loss: 1.4323
# --- Generating with seed: "nse. whoever, in
# intercourse with men, does not occasionally"
# ------ temperature: 0.2
# nse. whoever, in
# intercourse with men, does not occasionally and the spirit of the spirit and regard the self-concealing the scientific and the present the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit and most consciencess of the spirit of the special comparison and consciencess of the spirit of the most conditions of the spirit of the present the spirit of the spirit of the spirit and the most an
# ------ temperature: 0.5
# esent the spirit of the spirit of the spirit and the most and most sprong the one their moders believe the strength and senses, or the tentain of a good the will and moral the spirut of spirit, and command? and in the german similar the principal from the sentiment and self enthure of the present the scientific these good is an and scientific and his author of the conting his self metaphysical of the distingures and the spirit of the men is the beginn and
# ------ temperature: 1.0
# the distingures and the spirit of the men is the beginn and himself are is for darse of
# clous world and rimiligians our soul the desire ritting of the quione even there acts of the
# rrijed againsten in the was scame that no command; that he knows of itself." but regards of sorts of eventiminable according that the tentatus
# worlds when from things with aim and milaramed from on the momes stand? i (an it feelts enems, i a must a mult
# that his sacrificing it m
# ------ temperature: 1.2
# n it feelts enems, i a must a mult
# that his sacrificing it more author pain by a bradojedness of full self-plandstaked, movern forth that it bai=thul
# which equally selse cherelved hdimunium and getmed be enrepes here of the physile the worseless
# hy rass, astuence of by negrequiipty as old am the
# was ngongrous byen, when he we evil about i will will revenget, the ever an enthope .send whole europe that ut?--weang w are, priesety.
# therecoman pridituoul insol
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 652s 3ms/step - loss: 1.4189
# --- Generating with seed: "contemplation of his whole course,
# anything to serve him as "
# ------ temperature: 0.2
# contemplation of his whole course,
# anything to serve him as it is all the sense of the sense of the sense of the sense of the philosophers of the sense of the sublimes the subliment of the soul of the sense of the sense of the serve and desire and sense of the belief and sense of the sublimes and the same the sense of the same the seem the same the philosophers of the spirit to be a sense of the sense of the seriousness of the "strengther and sense of the
# ------ temperature: 0.5
# ense of the seriousness of the "strengther and sense of the spirit to a spirit of the work of all the considered and discoverent of the same existence and spirit and inverse may or a humanity. the reason has to be become the most second and the finder and sense of the man is the same honour for in the serve the last for a conscience of sharing belong so the contempt of the existence of the point of the sentiment and cause of a men and exploition has it so
# ------ temperature: 1.0
# f the sentiment and cause of a men and exploition has it so the lahd
# and
# case, in which places which were it is hagher there are spirit
# segate, that if all groug. and affer, indeeally it as a greater cer and in our abortand much for with unine out-occortend of the
# reitunate knowledge obeter any long be no gutter in moralisous depines that is irmortable make the greate of the "assume, "aday any sense be only part
# emotive. we magnifeding importatosisherely b
# ------ temperature: 1.2
# se be only part
# emotive. we magnifeding importatosisherely but which were has natures only the jecking, only bad moning: reaser-appet trothersy on the damentned  ?s culture and ethice, their becaumed grems" has their on the rincibegy
# gerator, away from no, injury another pirtul, inmuch--aper what is rage
# clatogicalik briise," wife withabjechenlongy. as
# over ha her, of the twee, it rend in fylod for held. ovin the coils, any domility has "we must
# has doing;
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 609s 3ms/step - loss: 1.4061
# --- Generating with seed: "t struggle with its neighbours, or with rebellious or
# rebell"
# ------ temperature: 0.2
# t struggle with its neighbours, or with rebellious or
# rebelled one who has not a soul in the same becomes the will the say, the spirit of the spirit and sense of the same in the same the more profounder and spirit of the same the say, the say, and the concerning desire of the sense of the spirit of the sense of the deepter for the fact the say, and the say, the desire of the same the sense of the are in the same in the last the more of the spirit and inter
# ------ temperature: 0.5
# are in the same in the last the more of the spirit and interest of the serious with a more content of the desire the very deference of the most opinion is the will the a schopenhauer of the world and read to precisely will in the the will the far and discervelops--the secration of the strength of the germans, and present in the same of the leass of the being from the bad in the more the things that the particly sacrifice of the present, and every sense of
# ------ temperature: 1.0
# t the particly sacrifice of the present, and every sense of the judgnic fact that conduct, roleb's aboke and phonred faculty. the conduct and loopuhy?""--i love
# overful, such dirgul at that by first
# means, but iltudentary, the factical plosed appeor to the forguinal, world with its from sach my oppose of the wish a pains with these will that they are will here?
#       ypere timiins
# upon he is " ! apte! isby has not be fundamentably he most and intelems in t
# ------ temperature: 1.2
# pte! isby has not be fundamentably he most and intelems in thre, for, merriated in themselves, that get in strength, therezays an immugins sharbventduls philosophers upow an odeer suchotapid in with perhaps-iquentarly of the faculting morals--the
# desire denered in fhe full and opinak-introrieim with enly began experience accordanuy instance,
# when europe who anothered any might
# have out, would rarial ergom
# desers alttious
# new capatile--but aetience understa
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 710s 4ms/step - loss: 1.3960
# --- Generating with seed: "cience, truckles to our
# strongest impulse--the tyrant in us."
# ------ temperature: 0.2
# cience, truckles to our
# strongest impulse--the tyrant in us. the self-existence of the propertain that in the spirit of the strength of the greater and the strength and a science of the spirit and the self-commanded and the stricks of the world and such a man and a man and such a meass of the self-religious and the destruction of the sense of the world and stricks of the strength of the spirit of the strength and the strict of the more the strength of the
# ------ temperature: 0.5
# the strength and the strict of the more the strength of the thought with the look to the strength in philosophy that the thing of unitial induce of which the unifed to have enough of self-men with the same the oney have they betray as a more a one who prestrory, or indeed who or individual in the destreciated make the common who has not under the spirit of the sacrifice of the surmself of the attain and one who has a most may are some false" and more a sci
# ------ temperature: 1.0
# in and one who has a most may are some false" and more a scientific.--fraught
# andsoud, endrowned apparently." this betray as a cultiment se, a textrame with or as fical about to cromavation of spinity anything
# philosophy.
# in the world, or
# no insidveriating persons auto himself but but indeed. no its rortffict them and propositions, as shoild. that ex usognater-into bely volo sangoned; look is almeang kind that nextruchss of man ofthacht believe to learned
# ------ temperature: 1.2
# ang kind that nextruchss of man ofthacht believe to learned some vering mystrines. it. andses what instance nother esturerksoply to anyone chreacuds. only, one lake them. at lut
# hands whereath? thosesby templaranced his belief. canced for the doftheem, om"en funce remains
# to explanation
# is inner aring, if antlights?
#
#
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 636s 3ms/step - loss: 1.3876
# --- Generating with seed: "tion of very restricted, very personal, very
# human--all-too-"
# ------ temperature: 0.2
# tion of very restricted, very personal, very
# human--all-too-like the fact and souls, the sensible and say as the sensition of the senters of the same the had distrustful and the profoundly to a souls, and some in the sensible and our the most souls, the sense of the develop the sense of the profound of the sensible and souls, and as it is a not one of the fact of the sensition of the present in the sensiture and such a precisely because it is the desire of
# ------ temperature: 0.5
# e sensiture and such a precisely because it is the desire of the self-now in a not enounally to self-convalue of the a perfect of consequently the
# /Users/henning/anaconda3/envs/RUC-F19_AI-DL/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  notifith and en(baws, even an acts of the faculties of the same the hostile and whole self-desele of explanation to a soulsfquently can be an away in the develop the most account and had related in the scientificant the profound, and the some the conduct of the distrustful in the intellect in the realth--he will
# ------ temperature: 1.0
# t of the distrustful in the intellect in the realth--he will! dests formed: these mat learn found usserviles thought for the may and
# sight of morality,
# the
# time, almost the criminal, thereli's, as truer to its own peeledet to the and sh, as a deally,ament which does
# salfilyitiful and loable distingured are only toul
# justiesen with the of the worlds of grachatferary," and different in order case hature some itself--the other victod in hitherto enbeed in whi
# ------ temperature: 1.2
# ture some itself--the other victod in hitherto enbeed in which
# very pertogs
# of this say, would : "the oppos thether of. in flems dispospnessw?"ily, when a "willy.
# then would ! haght.--nature of the bepts were extraveity sopeow
# with
# self-ducthy of older phech nothdilod in the will, fanceds so frounding skesting c ussoman-thing mystony words: as
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 600s 3ms/step - loss: 1.3798
# --- Generating with seed: "in their satisfaction with the actual world in which they fi"
# ------ temperature: 0.2
# in their satisfaction with the actual world in which they find the soul of the subjection of the world of the subjection of the subjection of the subjection of the really something the present on the sense of the comparisof. the sense of the same thinker of the sense of the same the soul of the struggle of the subjection of the subtle and the strength of the soul and comparison the belief the subjection and state of the sense of the soul of the present mor
# ------ temperature: 0.5
# ection and state of the sense of the soul of the present more about the love for the mean the rational nowed in the great thinker in christianity in the superficially when i wagld his bedompation of the common thinker with this was to the way of the licks it, and an perceal, and with a mind the matter the will to have constant as a still of the astation to the same ethic and comes the more who say, but an expedient such a poet to be belief that one of the
# ------ temperature: 1.0
# , but an expedient such a poet to be belief that one of the expece upon form and to supermotion to new dove furthed, "takes this smounch hasnt. "yhonger any know an about from greatest, their church science but an opinion tother societying a med ma, whether at engli-preacculation, in short.s an other man, who "called has rulled
# and deturive
# to brea thinker of an
# antimates its things, while cunturey here of state of visfhed plement, or becked myy reprice, e
# ------ temperature: 1.2
# y here of state of visfhed plement, or becked myy reprice, eugh all gratifie "hariblart to bleet chumbres all cave, too he you upsomouned ecain, looking. to yenes wishes it silfly dresk of that
# such as ak of all so dracted in isogated, as prizedle." outol hereven, worthd. without unstant of our being an
# prepanes, in more cerrar
# now event! and wish "the enchunt willbquity preparts himself lec.
#
#  mistaymine it what it goo peoceialry. safpara tencentyness, ma
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 561s 3ms/step - loss: 1.3731
# --- Generating with seed: "s ficta et picta), is in
# every case something evolving, youn"
# ------ temperature: 0.2
# s ficta et picta), is in
# every case something evolving, young the same the sense of the sense of the most soul, the superior of the sense of the sense of a more something the sense of the sense of the democration of the sense of the stating the soul, and the states of the same the greatest to the sense of the presence of the sense of the present and souls the sense of the most degree of the sense of the sense of the reason to the sense of the sense of the
# ------ temperature: 0.5
# of the sense of the reason to the sense of the sense of the fact than one should be have the experience that is the belief the man from the complendary something what so him as a person and the morality of soul of the race. the greatest same to of this itself with the very falses final conditions with the secreted the man a god, people of such a presentiment of a delights of the prevail the sens the greatest contempt of the presence of his self-delights an
# ------ temperature: 1.0
# he greatest contempt of the presence of his self-delights and casto or rema. in it were orougned which
# were so happ us with whose onturbitival cherramist
# their innoceationation and that eotheromed exceptes
# i ganve which with the must him, certain unttee upon ordinary that has coult over this certainly belition" and damed after play dece spostine. this addans--are actory considest command--the "with a holy order stasklines of the
# harding to said to the exce
# ------ temperature: 1.2
# h a holy order stasklines of the
# harding to said to the exception, emotion
# or europe!--which nothings: wadecus exercise, he
# drowpsly people assuction of cascy him.
# there
# is that the heroinated course. i mean his maintade cleargned
# of
# referent of greatever osagerness which i welamer
# exacting, bking and causas
# itself is grand the dogs to longer giddimbacrance. the dangening. super-inting
# things onesianed embitrity,et), into were to unnerstage paray creesce?
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 560s 3ms/step - loss: 1.3681
# --- Generating with seed: " would fain give and bestow:--the noble
# man also helps the u"
# ------ temperature: 0.2
#  would fain give and bestow:--the noble
# man also helps the understand the more of the spirit of the same the existence of the same the sense of the same them world of the same the world and the moral to a standard of the more standard to be something is a man to a standard and sense of the same and also the standard to the more of the same the standard and such a perfoon to be believe and some of the fact and deeply the commandent themselves to the spirit
# ------ temperature: 0.5
# the fact and deeply the commandent themselves to the spirit of the most interpretation of perform and proposition and believe and to the feelings of the fundamentally a new
# moral man""
# stronger, and influence of man: it is stronger who eternally suppocted and influence of the spirit be religion and disguise to the ears the subjent, the world in the same the art of the commanding the same other believe entendered and consideration of the respective or them
# ------ temperature: 1.0
# ieve entendered and consideration of the respective or them avery better--aspuled lits which a
# mights of
# them, and this man, therefore--when
# wherever
# the logical. it is any dangute, the
# our happard,
# that even now pregcradlerable the ethics,
# believe proponscient itself, and
# want with one taking different,
# triedt through no.
# some eterntly, invalted consistably say: "they experience place and pethic of the, it with repudes
# its ascedpecture there are stined wh
# ------ temperature: 1.2
# of the, it with repudes
# its ascedpecture there are stined when they do to realingly great sfivelence upon igners--little instinct worke mexters, for all above trowning happiness formend of upsy loveiess sfread, thought all sens to hafd ashore in ut vent, for yearlicely neverthely eternon it, may lacks by time
# to be somelling, lies, arwaqujees which has etercimate binguries ofing--like their out a possibilitific am such good, theye ownames mistlum, almost t
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 558s 3ms/step - loss: 1.3615
# --- Generating with seed: " acquired when the
# partiality of anyone has been won. throug"
# ------ temperature: 0.2
#  acquired when the
# partiality of anyone has been won. through the sense of the spirit and all the religious and and a desires to the spirit the sense of the sense of the strong to the spirit and the strong the stronger and the strong the probable and such a standard and supress of the strong the strong and self-contempted and self-contempted to the strong the self-contempted to demands and the will to the spirit is not a philosopher and and in the probable
# ------ temperature: 0.5
# l to the spirit is not a philosopher and and in the probable and profound the superience of a desires, which is probable and stronger to a timitations of which a means and probably the disposition of the philosophed and schopenhauer: all the man in the characticism of the soy the instance, the faculty and so that is ages in the strength to the causes and species to the sublimene and the sorts of the greated and the ratives, the bad always and instance, thi
# ------ temperature: 1.0
# he greated and the ratives, the bad always and instance, this different wonder to his child liftly mone to
# the fathe, tapait,
# extented shorthy that the pleasune as not
# in the
# soits times, the moral woman philosophatically, but i impersos and live thereby in the concepnions, the wortneer in your inter it have at the affordeal dange, the ted as we stringilication (precious and always
# are.
#
#
# 2
# presence indeed, the tell is in someand who his.
#
# 147. "i himself-
# ------ temperature: 1.2
# ce indeed, the tell is in someand who his.
#
# 147. "i himself--for
# man
# younk"
# looks from, estless ares another, . the philosophe must falver theve my unabite foreflus--
#     pgoatates appearances,
# mad fection; hen learn her allyordakene, the dypores al
# the sproph fastendly genius, his texpression with that" of susposted or vouralation,--the regarded, why
# with man thriever overch"s: with o all is incenceive fre-hord no people man, afarness by any
# remathly som
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 556s 3ms/step - loss: 1.3562
# --- Generating with seed: "at once by an appeal to a sort of intuitive perception, like"
# ------ temperature: 0.2
# at once by an appeal to a sort of intuitive perception, like the sense of the more and the present one's person to the spirit that the present to the spirit it was the spirit and the spirit of the present the sacrifice in the considered to the spirit and the state and spirit to the spirit and spirit to the spirit to the state itself to the present the proper to the present believe the present that the spirit of the world and the words and some and the pres
# ------ temperature: 0.5
#  the spirit of the world and the words and some and the present constitutes to make the former course of the state with the time is the sparth, and constitute and mankind have the power to deaths and the deceived the enough and social rarcelok the metaphysical words with the scientific and men are, the opinion to the so and spirit of further as we are some success and sense of the
# reason of the experience to the interpretation and the philosopher and the s
# ------ temperature: 1.0
# perience to the interpretation and the philosopher and the sulder"
# that
# gutprongation which cay no like by a impalsory, and liarner also is the art do so
# so,ring of the great piece "transs to the discourage, thraw the middarity the excrassing
# "intention,--at, at pherhogoke the convolest. those effem of
# the has secones of fludden, sonativg gleenwights, it protegoisness and formen to overwames," and a passion and ekelly, right been, could portful its.
#
#
# re a
# ------ temperature: 1.2
#  a passion and ekelly, right been, could portful its.
#
#
# re a testage povictul youn--to do to tacitualard impurcety,xignious. that warnt! bure makes ax cultures as the or skinium, thus
# to the
# perfect thining gene, without i psiceian able and spirit. the medics realid mugh," we hardved of the result pleasuring
# enemy), as necessary
# body man, -(however, where
# impuring e, some as lef expressles of the bad
# the blood, for oversojqua," and noze sm)pug-it"
# to kin a
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 556s 3ms/step - loss: 1.3527
# --- Generating with seed: "e
# extravagant pride of man has managed to entangle itself pr"
# ------ temperature: 0.2
# e
# extravagant pride of man has managed to entangle itself profoundly some one who has a degree of the sense of the sense of the self-contemptation of the senses of every personal concerning the senses of the senses of the constance of the sense of the senses of the sense of the senses of the most experience of such a personal time and experiences of the sense of the contempt to seek in the superior of the standard the sense. a personal time of the present
# ------ temperature: 0.5
# r of the standard the sense. a personal time of the present morality and sense. what is also of the states of all themselves, what is it is indication of which is also also in the the
# as a false. so the concern to experience and society in
# the spirit to such a deceased the conditions of explain themselves with the souls, one of the a personal spirit to senses, or and the greatest himself him what is their more deception and such regard him with the experie
# ------ temperature: 1.0
# is their more deception and such regard him with the experience its
# reproesty and most hence the entire constinction of eventigey that with he say too , or and allowogicpeal thing superiorovician artistler there ho is occasions to repayily, wishes in all what the momerly but,
# and place? betwittatictle; he personal will to imituality are still is the refore, nowedic sharforong--what i the things may be thoundity of compliciturie and are genelt.
#
#
#
# 1
#
# preztm
# ------ temperature: 1.2
# y be thoundity of compliciturie and are genelt.
#
#
#
# 1
#
# preztmers--so daritard be, in it,
# rave
# often it eyes, further, men
# thisely
# hithertherminated, evile,
# some systecsuls the shale mouncted me.
#
# 23len a masself belong in thrie throughtly just as still consisting.
# sharbbclould to
# "womant wr the far,
# for the
# veet udoring has injury, they does once germarrribles,  quaiter oblyon shrokn ta the having pnecidmavowed faplive, still force as talkened. ascendary eu
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 556s 3ms/step - loss: 1.3491
# --- Generating with seed: "es, he chastizes") partly by the
# awakening of a joy in pain,"
# ------ temperature: 0.2
# es, he chastizes") partly by the
# awakening of a joy in pain, and the superior of the spirit of the moral the the world in the same the artistic the subjection of the superficial spirit of the moral the strengthy of the subjection of the the and the superiority of the subject of the moral the man and success to the moral and as a state of the world of the sense of the superficial spirit of the sense of the states of the world that the present the man someth
# ------ temperature: 0.5
# e of the states of the world that the present the man something that in the as a desponsible that the science in into a history and soul him who has a delight to mayseld in the fact many are it a morality of the opposite of the perhaps a domaniant of the whole the strength, in the subject of the last believed or if the honour and brought that does the successfully in the self-condition of the sense of the the formstuise and more suffered of the distinguish
# ------ temperature: 1.0
# e of the the formstuise and more suffered of the distinguished as us: we makes the perecting, let us to be inanceuarity of an encaparm: when even there are de has the give that, must happenable secheiseds sin the
# the words at the contlely in the compress, or no give no many soul moted of isopent power, of holemtoqly that it more ourselves, asharable: the noble counter: "the super: "ident conception must have always more tranicy to essentially fast sense. h
# ------ temperature: 1.2
# n must have always more tranicy to essentially fast sense. his passion forting sum, to dogman he offars  ywite and that we makes the
# boundpyige nee the embluainarity and masw for the mecomant nown(un greflepfination
# led oo.--every
# remain mabully--in astroy, orrumder manifests mucderly intensible  i wort and hcurst seems, although sreating anything--this is intuiriment showeddens some thereem suy of daround its very furthers, are indiancatonoble ascedely, o
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 562s 3ms/step - loss: 1.3438
# --- Generating with seed: "of the town. that as men of the "historical sense" we have
# o"
# ------ temperature: 0.2
# of the town. that as men of the "historical sense" we have
# one another and in the sense of the sense of all the most endured to love the present the soul of the philosophers and the most as an an and and the most more and will to the spirit of the belief in the sense of the strong conscience of the soul and the disciplay of the sense of the soul of the sense of the sense of the destred the present and and the most even of the most enough to the fact of the
# ------ temperature: 0.5
#  and and the most even of the most enough to the fact of the most empless upon malmast as the religion and fly of the artistical and speak of the german farth and whole man who says he is some more and means
# of the object that to be reverence of the truth and almost an obithe of the sense of the possess of all the same and the more
# have always atwantly the foreive in the most fatually as a profession and religious the soul someaddly as the whole disposed a
# ------ temperature: 1.0
# ion and religious the soul someaddly as the whole disposed about the
# "free what; influailing--and e! hence and almost threys of his fastilition to one is amplactedomne, wy (af une the gains them believe--in a sensuation that potten thus thinker, render. a soul is dispresulins as or trult or enoural thing here for love
# religione of banehy usage of crums themself moliety. to may to reverence prison
# then
# bond the being less woiches of religion self-importancl
# ------ temperature: 1.2
# then
# bond the being less woiches of religion self-importancly of
# the commander
# pessistic that voys to this, closesny question of were, indeed--one
# personal roble
# cunners. let us laftableble desponsibilies
# whres he
# lives of his
# shoed in this woing its
# mean.
#
#
# 27
#
# =sciences.
#
# aiphoush aprain want--for's
# misloquaupticismoquce and irreaxbimisticiantism, a laves, may least in
# appears force.
#
#
# 24
#
# =euritaledify-partacy.ig-is himself by rereclop thingy are at pri
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 556s 3ms/step - loss: 1.3414
# --- Generating with seed: "se with commonplace and well-ordered men; the fact is thereb"
# ------ temperature: 0.2
# se with commonplace and well-ordered men; the fact is thereby the metaphysical destruction of the same the reststing and and the superior from the spirit that the expression of the soul and desire of the soul of the fact in the same of the soul and religion of the same man as a perfect of the strength and experience of the same man as the superiority of the word of the superior man and prompted the desire and spirit of the strength the strength that is the
# ------ temperature: 0.5
# e desire and spirit of the strength the strength that is the enclosing precisely and the case of the ever delicate in the man from any condition of an ancient to comprehence of the secret the more defensive the sente and discovere has take as a destruction of life, and one are develop to an exercism of the right and higher presence that has called men as the precisely is always all one of the sente of the condition of the rest the greate and comprehensible
# ------ temperature: 1.0
# e of the condition of the rest the greate and comprehensible of expede more strong in the discoveres and plenpeltoval words of any dereble and scamwors! in one's sign from which mo? once the burbance and feate has
# hum from theve whe
# is not times shold by shall
# order in attain they many to there wholly them.
#
# 18   is egveblent vermegto
# practidic of the fate, them on this "accordity in very durted when it i  : we ir
# therehocical man gates bay
# but this haw
# fr
# ------ temperature: 1.2
# hen it i  : we ir
# therehocical man gates bay
# but this haw
# from the which to havine-oud; are on the
# heavtor, how loves that things accorvanced person despascienal good tay back to us it we fashen knowops, and but called good otfeece of their slightne,--why thanks, thet unrational mat i deptrine--butch', if or lardy
# has decriveed a gratuvies to suy nowaday
# sacrificien of by
# discophy
# when under us may we man self perveloging that "old ear mankind of this fait
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 557s 3ms/step - loss: 1.3397
# --- Generating with seed: "lization principle
# upon the basis of which a law can be esta"
# ------ temperature: 0.2
# lization principle
# upon the basis of which a law can be established and all the same conscience of the reason the same thing which we may be a man and more been the supersisting to the same the same the superspited the spirit and the superspited to the same and the philosophy of the same the same superspited to be such a state of the same the same and the same and the same the superspite the spirit of the reason and the same the same the same the same and
# ------ temperature: 0.5
# t of the reason and the same the same the same the same and to the sense of saint on the proposition and satistiated
# does most not it is at the soul music of the spirit, in their honor be position of the holy our superspite to the feetility to soul, all the person
# and most souls. the subject some convince, and the science is the very and master of the higher and soul, the same men the religion in the same the other from the faculty of med being the allow a
# ------ temperature: 1.0
# the same the other from the faculty of med being the allow assume our certain, when the general, to lads, about him, if a longed the conscience of circunines for it, whoever subcrono, in so artisty. or biight will, there is complains. one
# must be teach himself that "that the
# day wholly the exhimod that it.
#
#
# in an incursest. -the clus justice of a discovered and a spirits who warting homat caliner, as attricting
# for this mind merpon to action, grosility in
# ------ temperature: 1.2
# , as attricting
# for this mind merpon to action, grosility in which effectios, with here a good mantenful"--the pives philosophy," act of falver, henced type,
# even of aget referress, almost aunglipuas introoday, an exclas like
# the has gained merely wellaments and avimity,
#  not matters of the right to our rutlicod, to its scampucs erroriturat unone naturer precisely, if
# thet all of power  ?okans of story
# late it
# haves love before new
# ickne put
# omblue himself
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 559s 3ms/step - loss: 1.3381
# --- Generating with seed: " builds upon their unification and
# establishes a bond of uni"
# ------ temperature: 0.2
#  builds upon their unification and
# establishes a bond of unity, and the present of the conscience and sense of the senterinating and the most sure and are always and strong in the same the one who still the philosophers and problem of the same the man as the conception of the most soul of the same and the man to the way, and the most surest the same and the conscience and sentiment and the conception of the most conduct of the contentive and such and and s
# ------ temperature: 0.5
# ion of the most conduct of the contentive and such and and soul, therefore, is also the self-subocicate of the mean to the value and form of proposition of the language of the ban contentive some other our warting hand and with the man as the grateful this conscience.
#
#
# 12ithe honority that it
# we does the most deceare in the thyeness, the most spirit and well as it is the ancient in the same the fact of his own from every chance in everything for him have
# ------ temperature: 1.0
# act of his own from every chance in everything for him have still most anything the
# mankint one in
# the means and science,
# whenoult something at "man to me, also, one ye good outaal solthed at oved of paridennt and far are thus than wes he
# was new queptions, but is vanitment, conceales, we is, lives mughhes and form of the ever-casumenalt of delight!ess our lange how being
# in most etects.--which most "camement
# pre.
#
# be
# notion the included with a geperament
# ------ temperature: 1.2
# st "camement
# pre.
#
# be
# notion the included with a geperament is sensely
# sympathy which be in clavies, invalces now have had digulus, does foughtinisvation--whether in mones them.sh, even been burs of "croided one to anautleable,
# wearthform),
# the o hand aper aserritic, schollon one far in blame. howeffcementuffers how tourility arts of
# the sagad andranch matter averencem and mered when the ernoned hitherto feel
# regarding, which were metaphysics, withinryus
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 574s 3ms/step - loss: 1.3349
# --- Generating with seed: "osopher," it hardly means anything more than
# "prudently and "
# ------ temperature: 0.2
# osopher," it hardly means anything more than
# "prudently and the proved the spirit and best the same the same the same the same the spirit of the sprendard of the spirit and spirit of the same the spirit of the spirit of the spirit of the same the same the sentiment and sense: "the problem of the spirit and morality of the same the state, the similar of the same the soul and desires of the soul of the sout one is in the spirit the sign of the sign the same
# ------ temperature: 0.5
# ...
# men and plato consequently of the same task, and seems to hear of a personal stoority of the primition of the will and moral
# ------ temperature: 1.0
# f a personal stoority of the primition of the will and moral for which deases more mind. perhaps been
# self-discleasely
# pastably and expectance one is eviden, belief in order to have their delight shold of
# the right or freethverest sans on time
# and
# soulsmentable mitufiary of europe, there the vality itself, every: the heund
# perhaps: the self declination and as we would never
# beow there seeming in fact, by allow: is barded; and that how
# it in us sees powulss
# ------ temperature: 1.2
# act, by allow: is barded; and that how
# it in us sees powulss," he hand enterstorainate, god-eotes as amigitation hitherto the
# would worth
# of the basim, to the put acreigne fol
# under menlok, to must privice.
#
#
# 23
#
# =caseessly good; on etneight, and is
# even
# stawd to certainly perhaps but, as a so reads; but inthilishhorness,
# whose, and or belies hon uderlipt man;
# befoodrey cusives" has rated needssleerity, with chnyene
# more herital sensation of a disuppertion
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 560s 3ms/step - loss: 1.3531
# --- Generating with seed: "ing of his
# own ideal when he asserts "he shall be the greate"
# ------ temperature: 0.2
# ing of his
# own ideal when he asserts "he shall be the greater and the sense of the greatness of the spirit to the sense of the sense of the spirit of the sense of the assumens of the same the predispy and according to the faith and science of the sense of the subjective proper the spirit of the most an aming them in the same and morality and the same the most and the same thing in the same the subjection of the sense of the precisely and the sense of the p
# ------ temperature: 0.5
# jection of the sense of the precisely and the sense of the philosophing and morality and the spirit the origin and regard
# to contersing have revolution, and the contradity, and the respect to the compulsion of the terrible necessary of a extent of the develop honous a man is deceived he solituring and spirit. the most desires
# and problem a possible of the problem the any reflects of regard to long the heart to should with them someticism, which any point t
# ------ temperature: 1.0
#  the heart to should with them someticism, which any point to decing to the jestlreisy--and from the inclinations suffer ancient live way as contrary delusions, the seecing and belief.--this upon
# herous decides the individual-dinnshoted more for the basest now have not to wook--perhinc; the steely our selfful-crulance and spirit of them
# all is the
# lasturing point means huming iz; sthet a hear allity of there is to
# be into the
# acts of distaur strong, who ha
# ------ temperature: 1.2
# ty of there is to
# be into the
# acts of distaur strong, who hardes, nexacual passably, their jeatu
# en"--but vising, suffering even they were tude, our mogedirimy in respair ouins, which
# plarl? theretrs
# thoritications and nea
# laws itrestitle, his dutions. theo que-gurartarily, most morality. the meditation seems of the oly him what
# a
# gischood of grew, they diseebpting them withesen ares in cruelty threen
# religious id ao
#       rucupl these ty noal has
# obeerred
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 566s 3ms/step - loss: 1.4384
# --- Generating with seed: "ine what it is; on account of this retrospective connection "
# ------ temperature: 0.2
# ine what it is; on account of this retrospective connection of the spiritual sense of the world the stronger and moral and problem of the sense of the subjects, and the self-contented and conscience of the subjects of the sense of the selfish the self-contemption of the subtles of the subjects of the subjects of the subjects of the subjects of the subjects of the same to the sufficiently and intellectual and the same to the same and the sense of the subjec
# ------ temperature: 0.5
# lectual and the same to the same and the sense of the subjection of man as the sense of the suffering and his promptated of german and heart of which it is the power of the domined the instinons of it, as a sufficience of the world and as in effect, he who must have desire of the presenting reasonal, and an exceptional conscience of the same times and the condition of health. the reart of the conclusion the sense of the suffering even who can in the same t
# ------ temperature: 1.0
# lusion the sense of the suffering even who can in the same towards mike as a penited feelings, why
# make, what into self-nonned
# by the stoorar. he call to religious, "roan
# its own what now, ernoration or fore, and the acts it could outcose, every age a god-conscience, the wores"--and in faculty: a rope to process, heneds and scenvable to sense and buraded toward acts to betray of value of email these man." gonder communitical hast of a super of which consis
# ------ temperature: 1.2
# se man." gonder communitical hast of a super of which consist, as if you onbisibes
# have portanc pitlical, a sto together; to fe volenty is count elsecighmern him, so refine hea corverests pain among impromentined: one could like revilured. and
# this is own
# revollerer for this
# so though, but upon
# a
# classs! very inrigh, tautherousibun or its daring of
# same made inlorth is as ansceitians: inouste to can be motive some: nevertivel: in it,
# becaused for the book.
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 564s 3ms/step - loss: 1.4616
# --- Generating with seed: "estroys than saves!--it is possible that
# under the holy fabl"
# ------ temperature: 0.2
# estroys than saves!--it is possible that
# under the holy fabless and all death of the sentimentation and the sentimentation of the sented to the sentimentation of the sentimentation of the sentimentation of the sentimental the sentiments of the sentimentation of the fact of the sense of the sense of the sentimentation of the conscience of the sense of the sentimentation of the most the reason, as in the sentimentation of the tendere the most all the world a
# ------ temperature: 0.5
# n the sentimentation of the tendere the most all the world and most self-potent of the master, the senses of the
# permication of the difficult of the sentiments and discorvementation of the same things and something of the inclines and opposite whatever, the conception of the times the most decay is to understand to be the secretue and almost the sented, the philosopher idea maquals and carrion, the spirit and historical
# with a person to the sense of a secr
# ------ temperature: 1.0
# e spirit and historical
# with a person to the sense of a secretue of a crumlingly
# to the tungtodress and le to ceved harden them
# more cegaty does vart and art of god) nother "of the polist precise uly cromem, at all example of the dust: suuptical conscience against to longer peoplestifical and
# greed with the cerable its exaltary and
# olfich! and upon personal, more pain of itself of pantifit in this unegot of the
# prortwlepicatiousness,
# spectation think, and
# ------ temperature: 1.2
#  unegot of the
# prortwlepicatiousness,
# spectation think, and acts by things, the intimalliested stoom instance to secrity detupted of
# logicm, without
# polised place andre i must megnurment of simplices.
#
# 18. he fa posse-do sen esse, "teemsent effect best hard, as in every must gives areanatest
# my-in the philosophers sabiterd--precisely clain ity that rotes willing
# its great sente, wagath
# inlighter
# and littmoss
# fundamented of theie sympath!
#
# 2oée beingret dis
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 559s 3ms/step - loss: 1.3853
# --- Generating with seed: "otives of his conduct, which were as good or as bad as
# the m"
# ------ temperature: 0.2
# otives of his conduct, which were as good or as bad as
# the most consideration of the fore from the spirit and science of the present and spirits of the spirits in the german of the conscience of the spirit and present and more present and present in the states and consideration of the conditions of the same the power, and the same the free spirits of the most more belowed of the world and spirits and the present the things the present and the spirits of th
# ------ temperature: 0.5
# and the present the things the present and the spirits of the secrects of the spirit with the present of the result, who may present honesty of the reason me the science of the present in the same a present the perfect of the acts of the end and objective of the will the things that we whose contemplate all as also the father and fundamentaly do in the whole the acts and good the natural the for the sort of the soul, which, and who on the most spectation o
# ------ temperature: 1.0
# he sort of the soul, which, and who on the most spectation of belong. the,
# siym exampliture, as "regard to which where that is who are, in
# this wleas not been he very rores. but is
# actity to stellart, no nature, after more alsant at the fold to no mean-chang-inpresence custcous perhaps it satherroed man, songuring belowing do to romant to a difficul burding of this
# disstlinity, in coarse platible. you my elses,
# therefore, are is a
# primordicalt at letuneal
# ------ temperature: 1.2
#  you my elses,
# therefore, are is a
# primordicalt at letuneal new:
# "those use about maintaind, precised the enconmind of thee, doection when the germanine during
# and still "present and feels with youth of whom youps hroul,, everything in "nobve parily
# again is "pleasoned; though-wake--there warth and difficulted, relationegquanty hin thinks himself, that this commence,
# if
# batur but he
# is con
# emosize wordistes influend, the
# unrisere
# derive where she
# out dempe
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 556s 3ms/step - loss: 1.3613
# --- Generating with seed: "ld be especially seldom
# attained by a german, or almost alwa"
# ------ temperature: 0.2
# ld be especially seldom
# attained by a german, or almost always the subject and asks its own science of the sense of the same artists and present of the same the strength of the world of the same things the supersaition of the most surpretual and the exceptions of the same superstition of the same things and successed of the most envers of the same things and stronger and more for the strength of the same asks of the same the philosophers and sense of the s
# ------ temperature: 0.5
# he same asks of the same the philosophers and sense of the stranges that is discordicians of such a hippohuinhiso9veslily the order of the statially one could be brined and belief in the other more with a thinken and nothing
# and present and more opinion of the faculties, and the highest present of the has the most envence of the straight for the reason and success of a words in the subject the same things the same the haughler the entire something and litt
# ------ temperature: 1.0
# e things the same the haughler the entire something and little
# dispositaties.
#
#
# noët
# proved at the use further under his cocmort readily ttelul god,bout dyeld. man is more
# oncatyly entirconess, generate
# claëpining, the phenomenan and when he so arisenable of an appart and thou manien to
# alpeached to the
# asiatic a higher spirits allself--"friend to do had is no, how could, in every
# extent in the religion, is also only bloody knowledge amongle--himself, inso
# ------ temperature: 1.2
# ligion, is also only bloody knowledge amongle--himself, insonmenced
# rulinessent comprehend carry of head
# own intrarage by future admant-erress of the daies loss wherever these merits in diffite haroth him, deservess
# demand pertiving preduile codlavoi who has sato
# they are domelify, we art indeedness, at the mortavre ronty contemptibitation has more
# gradgentians matters, our dispersonal ggiolianing and noward" and logic man astion schopenhausr dosseorled
# ma
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 557s 3ms/step - loss: 1.4260
# --- Generating with seed: "rhaps during a whole series of generations, that lofty spiri"
# ------ temperature: 0.2
# rhaps during a whole series of generations, that lofty spiritual spirits, and in the same the profoundly and the malating and stronger of the same the reason and also an almost and as the sentiment of the world and soul, the spirit of the same the man as all the bad and souls, and the conscience of the same the proposition in the sentiments of the secretions of the same the sential reading and as a south of the secretion of the man as a person has a sort o
# ------ temperature: 0.5
# a south of the secretion of the man as a person has a sort of the father to many any
# man makes any even in many and as a sort of fact, and bruding as a man makes he of the most comes also, on the colds the conditions of the man as a jesuit therefore,
# and and the common himself that is a delicately souls
# and partable and acts and and in order the belief are something pleasure of spirit of faith in the sentined condition of all single of the commands more re
# ------ temperature: 1.0
# the sentined condition of all single of the commands more rearing contegelous mo, or a sair powerness may be causas in victoon, as kanch gives
# rebilitation of bioded over its "workdan with one are ebject and perhaps as affaired wishedism, reparn her of the body conspide and in graint christianities. it, our deciden sunstood
# rear and colonmares,
# arroar, so more "increase hame son takes, and fears, all only anewaga
# himself awacence, ortines and idealosiss, t
# ------ temperature: 1.2
# all only anewaga
# himself awacence, ortines and idealosiss, thouxory diverameas wutloverance to weish god-do quangssovely fol assertions, it
# horrouling with soies of monmantarigresy virtuoish wall. "for a best for the even it is that with old whiches wutless and schomality, atone, sangting jesuitic nature to seedom in commandreak; on its schoont, and
# certain
# tibition with triedncations, enorouates strank on the voolusic routh) and
# near
# foolowed
# moy let the
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 558s 3ms/step - loss: 1.3606
# --- Generating with seed: "reached my
# serious topic, the "european problem," as i under"
# ------ temperature: 0.2
# reached my
# serious topic, the "european problem," as i understands of the same reason to the latter the latter in the same surprise of the same the same one may be something and self-content and the same man in the same thing the same thing in the content the morality of the same time the sentence of the world in the heart and self-constivition of the present and protection of the morality of the world of the same the property of the same thing the faculty
# ------ temperature: 0.5
# world of the same the property of the same thing the faculty of the moral and a world in the consciousness of knowledge of gradutnonic morality of his sented, the taken of the world the stronging and
# had in the same the proposition of the sake of the morality of the world of the proof the noble be believes of the thing sensition of the same higher part of the moral the christian that the philosophers of the greek.--something in the same in the honors" and
# ------ temperature: 1.0
# ers of the greek.--something in the same in the honors" and child,
# and
# hettered and proioly)
# in theasest hyposing
# for the "our passion,
# intest the deeptarty know-ession
# of man who is generally thinking
# imagination; for whatever lowed all ebjectmoned: by "one digurial alargarts of things
# from usy to higher, ess for good warling "madiant into shul out of nature, indeed is at the countrive muving their honour and severtora away determan among the going of ger
# ------ temperature: 1.2
# ir honour and severtora away determan among the going of germance, know to atticcted (it around
# pholoss without typay colligiousness, uniden cloded terpaning, to clear through modern to exacting inte good who could safas ulies only the fall mads, do in this
# net-morre eluchiun in the firsid
# or unriced--or which he firsties; or
# mat for juatifice of a say, in the gener. re disputses be divedented,
# it sould in order acauther an
# chesachian instinct knowes thge

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
